# %%
import requests
import os
import json
import pandas as pd
import time
import codecs
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import random

# %%
bearer_token = 'AAAAAAAAAAAAAAAAAAAAANCQfwEAAAAA7RkAI9ZAZWRBpLh585MXewWNe%2Fc%3DkeeHZZ7OHkBJPmA0SwaF2Mt83z2tYol75ECHHAsUAZ7OamvlEF'

# %%
os.chdir('Documents/20221127_china_city_tweets/')

# %%
def create_url(idlook):
    idstr = str(idlook)
    url = 'https://api.twitter.com/2/users/' + idstr
    return url


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2UserLookupPython"
    return r


def connect_to_endpoint(url, params):
    response = requests.request("GET", url, auth=bearer_oauth, params = params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()

# %%
query_params = {
                "user.fields":'created_at'
    
}

# %%
json_response = connect_to_endpoint('https://api.twitter.com/2/users/1524462202912137218', query_params)
# Out:
# 200

# %%
pd.DataFrame(json_response).transpose()
# Out:
#                     created_at                   id               name  \
# data  2022-05-11T18:51:27.000Z  1524462202912137218  上海 Eunice Bertram
#
#             username
# data  EuniceBertram3

# %%
tweets = pd.read_csv('2022-11-28_beishangguang_tweets_without_retweets_2022-11-21T170300Z_2022-11-25T215101Z.csv')
# Out:
# C:\Users\jhuo\AppData\Local\Continuum\anaconda2\envs\python3\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tweetsauthors = list(tweets.author_id.unique())

# %%
len(tweetsauthors)
# Out:
# 105911

# %%
userdf = pd.DataFrame()

# %%
for user in tweetsauthors[27:]:
    url = create_url(user)
    res = connect_to_endpoint(url, query_params)
    resdf = pd.DataFrame(res).transpose()
    userdf = userdf.append(resdf)
    print(tweetsauthors.index(user))
    time.sleep(3)
# Out:
# 200
# 27
# 200
# 28
# 200
# 29
# 200
# 30
# 200
# 31
# 200
# 32
# 200
# 33
# 200
# 34
# 200
# 35
# 200
# 36
# 200
# 37
# 200
# 38
# 200
# 39
# 200
# 40
# 200
# 41
# 200
# 42
# 200
# 43
# 200
# 44
# 200
# 45
# 200
# 46
# 200
# 47
# 200
# 48
# 200
# 49
# 200
# 50
# 200
# 51
# 200
# 52
# 200
# 53
# 200
# 54
# 200
# 55
# 200
# 56
# 200
# 57
# 200
# 58
# 200
# 59
# 200
# 60
# 200
# 61
# 200
# 62
# 200
# 63
# 200
# 64
# 200
# 65
# 200
# 66
# 200
# 67
# 200
# 68
# 200
# 69
# 200
# 70
# 200
# 71
# 200
# 72
# 200
# 73
# 200
# 74
# 200
# 75
# 200
# 76
# 200
# 77
# 200
# 78
# 200
# 79
# 200
# 80
# 200
# 81
# 200
# 82
# 200
# 83
# 200
# 84
# 200
# 85
# 200
# 86
# 200
# 87
# 200
# 88
# 200
# 89
# 200
# 90
# 200
# 91
# 200
# 92
# 200
# 93
# 200
# 94
# 200
# 95
# 200
# 96
# 200
# 97
# 200
# 98
# 200
# 99
# 200
# 100
# 200
# 101
# 200
# 102
# 200
# 103
# 200
# 104
# 200
# 105
# 200
# 106
# 200
# 107
# 200
# 108
# 200
# 109
# 200
# 110
# 200
# 111
# 200
# 112
# 200
# 113
# 200
# 114
# 200
# 115
# ...

# %%
for user in tweetsauthors[7930:]:
    url = create_url(user)
    res = connect_to_endpoint(url, query_params)
    resdf = pd.DataFrame(res).transpose()
    userdf = userdf.append(resdf)
    print(tweetsauthors.index(user))
    time.sleep(1)
# Out:
# 200
# 7930
# 200
# 7931
# 200
# 7932
# 200
# 7933
# 200
# 7934
# 200
# 7935
# 200
# 7936
# 200
# 7937
# 200
# 7938
# 200
# 7939
# 200
# 7940
# 200
# 7941
# 200
# 7942
# 200
# 7943
# 200
# 7944
# 200
# 7945
# 200
# 7946
# 200
# 7947
# 200
# 7948
# 200
# 7949
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-2a54176bb4e2> in <module>
#       1 for user in tweetsauthors[7930:]:
#       2     url = create_url(user)
# ----> 3     res = connect_to_endpoint(url, query_params)
#       4     resdf = pd.DataFrame(res).transpose()
#       5     userdf = userdf.append(resdf)
#
# <ipython-input-58-dfb67f1cd66d> in connect_to_endpoint(url, params)
#      16
#      17 def connect_to_endpoint(url, params):
# ---> 18     response = requests.request("GET", url, auth=bearer_oauth, params = params)
#      19     print(response.status_code)
# ...

# %%
for user in tweetsauthors[7949:]:
    url = create_url(user)
    res = connect_to_endpoint(url, query_params)
    resdf = pd.DataFrame(res).transpose()
    userdf = userdf.append(resdf)
    print(tweetsauthors.index(user))
    time.sleep(1)
# Out:
# 200
# 7949
# 200
# 7950
# 200
# 7951
# 200
# 7952
# 200
# 7953
# 200
# 7954
# 200
# 7955
# 200
# 7956
# 200
# 7957
# 200
# 7958
# 200
# 7959
# 200
# 7960
# 200
# 7961
# 200
# 7962
# 200
# 7963
# 200
# 7964
# 200
# 7965
# 200
# 7966
# 200
# 7967
# 200
# 7968
# 200
# 7969
# 200
# 7970
# 200
# 7971
# 200
# 7972
# 200
# 7973
# 200
# 7974
# 200
# 7975
# 200
# 7976
# 200
# 7977
# 200
# 7978
# 200
# 7979
# 200
# 7980
# 200
# 7981
# 200
# 7982
# 200
# 7983
# 200
# 7984
# 200
# 7985
# 200
# 7986
# 200
# 7987
# 200
# 7988
# 200
# 7989
# 200
# 7990
# 200
# 7991
# 200
# 7992
# 200
# 7993
# 200
# 7994
# 200
# 7995
# 200
# 7996
# 200
# 7997
# 200
# 7998
# 200
# 7999
# 200
# 8000
# 200
# 8001
# 200
# 8002
# 200
# 8003
# 200
# 8004
# 200
# 8005
# 200
# 8006
# 200
# 8007
# 200
# 8008
# 200
# 8009
# 200
# 8010
# 200
# 8011
# 200
# 8012
# 200
# 8013
# 200
# 8014
# 200
# 8015
# 200
# 8016
# 200
# 8017
# 200
# 8018
# 200
# 8019
# 200
# 8020
# 200
# 8021
# 200
# 8022
# 200
# 8023
# 200
# 8024
# 200
# ...

# %%
for user in tweetsauthors[8197:]:
    url = create_url(user)
    res = connect_to_endpoint(url, query_params)
    resdf = pd.DataFrame(res).transpose()
    userdf = userdf.append(resdf)
    print(tweetsauthors.index(user))
    time.sleep(1)
# Out:
# 200
# 8197
# 200
# 8198
# 200
# 8199
# 200
# 8200
# 200
# 8201
# 200
# 8202
# 200
# 8203
# 200
# 8204
# 200
# 8205
# 200
# 8206
# 200
# 8207
# 200
# 8208
# 200
# 8209
# 200
# 8210
# 200
# 8211
# 200
# 8212
# 200
# 8213
# 200
# 8214
# 200
# 8215
# 200
# 8216
# 200
# 8217
# 200
# 8218
# 200
# 8219
# 200
# 8220
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-b1a2d152628d> in <module>
#       1 for user in tweetsauthors[8197:]:
#       2     url = create_url(user)
# ----> 3     res = connect_to_endpoint(url, query_params)
#       4     resdf = pd.DataFrame(res).transpose()
#       5     userdf = userdf.append(resdf)
#
# <ipython-input-58-dfb67f1cd66d> in connect_to_endpoint(url, params)
#      16
#      17 def connect_to_endpoint(url, params):
# ---> 18     response = requests.request("GET", url, auth=bearer_oauth, params = params)
# ...

# %% [markdown]
# switching lanes and focus on the ones since 25ht

# %%
list1 = [x for x in os.listdir() if "without_retweets" in x]

# %%
list2 = [x for x in list1 if "2022-11-21T170300Z_2022-11-25T215101Z" not in x]

# %%
list2
# Out:
# ['2022-11-28_beishangguang_tweets_without_retweets_2022-11-21T190300Z_2022-11-22T154738Z.csv',
#  '2022-11-28_beishangguang_tweets_without_retweets_2022-11-21T220300Z_2022-11-22T132521Z.csv',
#  '2022-11-29_beishangguang_tweets_without_retweets_2022-11-27T000000Z_2022-11-28T210000Z.csv']

# %%
for path in list2:
    df = pd.read_csv(path)
    tweets = tweets.append(df)
# Out:
# C:\Users\jhuo\AppData\Local\Continuum\anaconda2\envs\python3\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tweets = tweets.drop('Unnamed: 0', axis = 1)

# %%
tweets = tweets.drop_duplicates()

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2636387 entries, 0 to 1103566
# Data columns (total 21 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   referenced_tweets       object
#  1   created_at              object
#  2   conversation_id         int64
#  3   reply_settings          object
#  4   author_id               int64
#  5   edit_history_tweet_ids  object
#  6   entities                object
#  7   possibly_sensitive      bool
#  8   lang                    object
#  9   attachments             object
#  10  text                    object
#  11  id                      int64
#  12  source                  object
#  13  context_annotations     object
#  14  in_reply_to_user_id     float64
#  15  geo                     object
#  16  withheld                object
#  17  retweet_count           int64
#  18  reply_count             int64
#  19  like_count              int64
#  20  quote_count             int64
# ...

# %%
tweets.created_at = [pd.to_datetime(x) for x in tweets.created_at]

# %%
cutoff = pd.to_datetime('2022-11-24T11:50:00Z')
# tweets after 2022-11-24 11:50
afterfire = tweets[tweets.created_at >= cutoff]
# identify the authorid
afterfireid = list(afterfire.author_id.unique())

# %%
len(afterfireid)
# Out:
# 211977

# %%
afterfireid1 = [str(x) for x in afterfireid]

# %%
# identify the author id that hasn't been processed yet
# find their screennames
processed = list(userdf.id.unique())

# %%
len(processed)
# Out:
# 8205

# %%
processed[0]
# Out:
# '958706712474734595'

# %%
len(processed)
# Out:
# 8205

# %%
to_process = [x for x in afterfireid1 if x not in processed]

# %%
len(to_process)
# Out:
# 203896

# %%
for user in to_process:
    url = create_url(user)
    res = connect_to_endpoint(url, query_params)
    resdf = pd.DataFrame(res).transpose()
    userdf = userdf.append(resdf)
    print(to_process.index(user))
    time.sleep(1)
# Out:
# 200
# 0
# 200
# 1
# 200
# 2
# 200
# 3
# 200
# 4
# 200
# 5
# 200
# 6
# 200
# 7
# 200
# 8
# 200
# 9
# 200
# 10
# 200
# 11
# 200
# 12
# 200
# 13
# 200
# 14
# 200
# 15
# 200
# 16
# 200
# 17
# 200
# 18
# 200
# 19
# 200
# 20
# 200
# 21
# 200
# 22
# 200
# 23
# 200
# 24
# 200
# 25
# 200
# 26
# 200
# 27
# 200
# 28
# 200
# 29
# 200
# 30
# 200
# 31
# 200
# 32
# 200
# 33
# 200
# 34
# 200
# 35
# 200
# 36
# 200
# 37
# 200
# 38
# 200
# 39
# 200
# 40
# 200
# 41
# 200
# 42
# 200
# 43
# 200
# 44
# 200
# 45
# 200
# 46
# 200
# 47
# 200
# 48
# 200
# 49
# 200
# 50
# 200
# 51
# 200
# 52
# 200
# 53
# 200
# 54
# 200
# 55
# 200
# 56
# 200
# 57
# 200
# 58
# 200
# 59
# 200
# 60
# 200
# 61
# 200
# 62
# 200
# 63
# 200
# 64
# 200
# 65
# 200
# 66
# 200
# 67
# 200
# 68
# 200
# 69
# 200
# 70
# 200
# 71
# 200
# 72
# 200
# 73
# 200
# 74
# 200
# 75
# 200
# 76
# 200
# 77
# 200
# 78
# 200
# 79
# 200
# 80
# 200
# 81
# 200
# 82
# 200
# 83
# 200
# 84
# 200
# 85
# 200
# 86
# 200
# 87
# 200
# 88
# 200
# 89
# 200
# 90
# 200
# ...

# %% [markdown]
# # new approach - random sampling, controlled by hourly volumnes

# %%
tweets.created_at.min()
# Out:
# Timestamp('2022-11-21 22:03:00+0000', tz='UTC')

# %%
tweets.created_at.max()
# Out:
# Timestamp('2022-11-28 20:59:59+0000', tz='UTC')

# %%
tweets['date'] = [x.date() for x in tweets.created_at]
tweets['hour'] = [x.hour for x in tweets.created_at]
tweets['date_hour'] = [str(x) + '-' + str(y) for (x,y) in zip(tweets.date, tweets.hour)]

# %%
def show_chart(df):
    volbydate = pd.DataFrame(df.groupby('date_hour').created_at.count())
    volbydate = volbydate.sort_values('date_hour')
    volbydate = volbydate.reset_index()
    fig, axs = plt.subplots(1, 1,figsize=(20, 6))
    sns.barplot(volbydate.date_hour, volbydate.created_at, color = 'grey')
    plt.xticks(rotation= 45)

# %%
print('Hourly tweet volume')
show_chart(tweets)
# Out:
# Hourly tweet volume

# %% [markdown]
# how about users?

# %%
useriddf = tweets[['date_hour','author_id']].drop_duplicates()

# %%
usercount = pd.DataFrame(useriddf.groupby('date_hour').author_id.count())

# %%
usercount = usercount.reset_index()

# %%
usercount.head()
# Out:
#        date_hour  author_id
# 0  2022-11-21-22        897
# 1  2022-11-21-23       1060
# 2   2022-11-22-0       1172
# 3   2022-11-22-1       1356
# 4  2022-11-22-10       2052

# %%
print('Hourly user count')
fig, axs = plt.subplots(1, 1,figsize=(20, 6))
sns.barplot(usercount.date_hour, usercount.author_id, color = 'grey')
plt.xticks(rotation= 45);
# Out:
# Hourly user count

# %% [markdown]
# We can see that the volume of tweets have risen, but not as dramatically as the volume of users

# %% [markdown]
# Taking a sampling of...the tweets? the users? their interaction? Or just using the network graphs?

# %% [markdown]
# taking a sampling of users by hour, and if a spammy account posts a lot then we'll see....

# %%
userbyhour = pd.DataFrame(useriddf.groupby('date_hour').author_id.unique())

# %%
userbyhour.head()
# Out:
#                                                        author_id
# date_hour
# 2022-11-21-22  [1144696833588903936, 1572752280381702147, 150...
# 2022-11-21-23  [1156166393798094848, 1316704549374103554, 146...
# 2022-11-22-0   [1531024932884434956, 1087714082055024641, 155...
# 2022-11-22-1   [1519702168378515456, 1539305919661518853, 980...
# 2022-11-22-10  [1421333745794048003, 1260911498198544385, 149...

# %%
userbyhour['idcount'] = [len(x) for x in userbyhour.author_id]

# %%
userbyhour.idcount.min()
# Out:
# 861

# %% [markdown]
# getting one percents seems ok?

# %%
def get_sample(x,y):
    listi = list(x)
    return(random.sample(listi, y))

# %%
userbyhour['samplecount'] = [round(x/100) for x in userbyhour.idcount]

# %%
userbyhour['samplelist'] = [get_sample(x,y) for (x,y) in zip(userbyhour.author_id, userbyhour.samplecount)]

# %%
flatten = lambda t: [item for sublist in t for item in sublist]

# %%
allsampleids = flatten(userbyhour.samplelist)

# %%
len(allsampleids)
# Out:
# 6496

# %%
allsampleidsdf = pd.DataFrame(allsampleids).drop_duplicates()

# %%
allsampleidsdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6138 entries, 0 to 6495
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       6138 non-null   int64
# dtypes: int64(1)
# memory usage: 95.9 KB

# %%
allsampleidsdflist = list(allsampleidsdf[0])

# %%
allsampleidsdflist = [str(x) for x in allsampleidsdflist]

# %%
sample_to_process = [x for x in allsampleidsdflist if x not in processed]

# %%
len(sample_to_process)
# Out:
# 5449

# %%
for user in sample_to_process:
    url = create_url(user)
    res = connect_to_endpoint(url, query_params)
    resdf = pd.DataFrame(res).transpose()
    userdf = userdf.append(resdf)
    print(sample_to_process.index(user))
    time.sleep(2)
# Out:
# 200
# 0
# 200
# 1
# 200
# 2
# 200
# 3
# 200
# 4
# 200
# 5
# 200
# 6
# 200
# 7
# 200
# 8
# 200
# 9
# 200
# 10
# 200
# 11
# 200
# 12
# 200
# 13
# 200
# 14
# 200
# 15
# 200
# 16
# 200
# 17
# 200
# 18
# 200
# 19
# 200
# 20
# 200
# 21
# 200
# 22
# 200
# 23
# 200
# 24
# 200
# 25
# 200
# 26
# 200
# 27
# 200
# 28
# 200
# 29
# 200
# 30
# 200
# 31
# 200
# 32
# 200
# 33
# 200
# 34
# 200
# 35
# 200
# 36
# 200
# 37
# 200
# 38
# 200
# 39
# 200
# 40
# 200
# 41
# 200
# 42
# 200
# 43
# 200
# 44
# 200
# 45
# 200
# 46
# 200
# 47
# 200
# 48
# 200
# 49
# 200
# 50
# 200
# 51
# 200
# 52
# 200
# 53
# 200
# 54
# 200
# 55
# 200
# 56
# 200
# 57
# 200
# 58
# 200
# 59
# 200
# 60
# 200
# 61
# 200
# 62
# 200
# 63
# 200
# 64
# 200
# 65
# 200
# 66
# 200
# 67
# 200
# 68
# 200
# 69
# 200
# 70
# 200
# 71
# 200
# 72
# 200
# 73
# 200
# 74
# 200
# 75
# 200
# 76
# 200
# 77
# 200
# 78
# 200
# 79
# 200
# 80
# 200
# 81
# 200
# 82
# 200
# 83
# 200
# 84
# 200
# 85
# 200
# 86
# 200
# 87
# 200
# 88
# 200
# 89
# 200
# 90
# 200
# ...

# %%
for user in sample_to_process[301:]:
    url = create_url(user)
    res = connect_to_endpoint(url, query_params)
    resdf = pd.DataFrame(res).transpose()
    userdf = userdf.append(resdf)
    print(sample_to_process.index(user))
    time.sleep(3)
# Out:
# 200
# 301
# 200
# 302
# 200
# 303
# 200
# 304
# 200
# 305
# 200
# 306
# 200
# 307
# 200
# 308
# 200
# 309
# 200
# 310
# 200
# 311
# 200
# 312
# 200
# 313
# 200
# 314
# 200
# 315
# 200
# 316
# 200
# 317
# 200
# 318
# 200
# 319
# 200
# 320
# 200
# 321
# 200
# 322
# 200
# 323
# 200
# 324
# 200
# 325
# 200
# 326
# 200
# 327
# 200
# 328
# 200
# 329
# 200
# 330
# 200
# 331
# 200
# 332
# 200
# 333
# 200
# 334
# 200
# 335
# 200
# 336
# 200
# 337
# 200
# 338
# 200
# 339
# 200
# 340
# 200
# 341
# 200
# 342
# 200
# 343
# 200
# 344
# 200
# 345
# 200
# 346
# 200
# 347
# 200
# 348
# 200
# 349
# 200
# 350
# 200
# 351
# 200
# 352
# 200
# 353
# 200
# 354
# 200
# 355
# 200
# 356
# 200
# 357
# 200
# 358
# 200
# 359
# 200
# 360
# 200
# 361
# 200
# 362
# 200
# 363
# 200
# 364
# 200
# 365
# 200
# 366
# 200
# 367
# 200
# 368
# 200
# 369
# 200
# 370
# 200
# 371
# 200
# 372
# 200
# 373
# 200
# 374
# 200
# 375
# 200
# 376
# 200
# 377
# 200
# 378
# 200
# 379
# 200
# 380
# 200
# 381
# 200
# 382
# 200
# 383
# ...

# %% [markdown]
# two prongs - both sampling users and pulling user names AND getting the network graphs

# %% [markdown]
# sampling again since I have more time

# %%
userbyhour['samplecount2'] = [round(x/50) for x in userbyhour.idcount]

# %%
userbyhour['samplelist2'] = [get_sample(x,y) for (x,y) in zip(userbyhour.author_id, userbyhour.samplecount2)]

# %%
allsampleids2 = flatten(userbyhour.samplelist2)

# %%
len(allsampleids2)
# Out:
# 12998

# %%
allsampleidsdf2 = pd.DataFrame(allsampleids2).drop_duplicates()

# %%
# identify the author id that hasn't been processed yet
# find their screennames
processed = list(userdf.id.unique())

# %%
len(processed)
# Out:
# 13103

# %%
allsampleidsdf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11726 entries, 0 to 12997
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       11726 non-null  int64
# dtypes: int64(1)
# memory usage: 183.2 KB

# %%
allsampleidsdflist2 = list(allsampleidsdf2[0])

# %%
allsampleidsdflist2 = [str(x) for x in allsampleidsdflist2]

# %%
sample_to_process2 = [x for x in allsampleidsdflist2 if x not in processed]

# %%
len(sample_to_process2)
# Out:
# 9942

# %%
for user in sample_to_process2[3:]:
    url = create_url(user)
    res = connect_to_endpoint(url, query_params)
    resdf = pd.DataFrame(res).transpose()
    userdf = userdf.append(resdf)
    print(sample_to_process2.index(user))
    time.sleep(3)
# Out:
# 200
# 3
# 200
# 4
# 200
# 5
# 200
# 6
# 200
# 7
# 200
# 8
# 200
# 9
# 200
# 10
# 200
# 11
# 200
# 12
# 200
# 13
# 200
# 14
# 200
# 15
# 200
# 16
# 200
# 17
# 200
# 18
# 200
# 19
# 200
# 20
# 200
# 21
# 200
# 22
# 200
# 23
# 200
# 24
# 200
# 25
# 200
# 26
# 200
# 27
# 200
# 28
# 200
# 29
# 200
# 30
# 200
# 31
# 200
# 32
# 200
# 33
# 200
# 34
# 200
# 35
# 200
# 36
# 200
# 37
# 200
# 38
# 200
# 39
# 200
# 40
# 200
# 41
# 200
# 42
# 200
# 43
# 200
# 44
# 200
# 45
# 200
# 46
# 200
# 47
# 200
# 48
# 200
# 49
# 200
# 50
# 200
# 51
# 200
# 52
# 200
# 53
# 200
# 54
# 200
# 55
# 200
# 56
# 200
# 57
# 200
# 58
# 200
# 59
# 200
# 60
# 200
# 61
# 200
# 62
# 200
# 63
# 200
# 64
# 200
# 65
# 200
# 66
# 200
# 67
# 200
# 68
# 200
# 69
# 200
# 70
# 200
# 71
# 200
# 72
# 200
# 73
# 200
# 74
# 200
# 75
# 200
# 76
# 200
# 77
# 200
# 78
# 200
# 79
# 200
# 80
# 200
# 81
# 200
# 82
# 200
# 83
# 200
# 84
# 200
# 85
# 200
# 86
# 200
# 87
# 200
# 88
# 200
# 89
# 200
# 90
# 200
# 91
# 200
# 92
# 200
# 93
# 200
# ...

# %% [raw]
# userdf.to_csv('20221130_usersamples.csv')

# %% [markdown]
# sampling a third time since I have more time!

# %%
userbyhour['samplecount3'] = [round(x/50) for x in userbyhour.idcount]

# %%
userbyhour['samplelist3'] = [get_sample(x,y) for (x,y) in zip(userbyhour.author_id, userbyhour.samplecount3)]

# %%
allsampleids3 = flatten(userbyhour.samplelist3)

# %%
len(allsampleids3)
# Out:
# 12998

# %%
allsampleidsdf3 = pd.DataFrame(allsampleids3).drop_duplicates()

# %%
# identify the author id that hasn't been processed yet
# find their screennames
processed = list(userdf.id.unique())

# %%
len(processed)
# Out:
# 21890

# %%
allsampleidsdf3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11642 entries, 0 to 12997
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       11642 non-null  int64
# dtypes: int64(1)
# memory usage: 181.9 KB

# %%
allsampleidsdflist3 = list(allsampleidsdf3[0])

# %%
allsampleidsdflist3 = [str(x) for x in allsampleidsdflist3]

# %%
sample_to_process3 = [x for x in allsampleidsdflist3 if x not in processed]

# %%
len(sample_to_process3)
# Out:
# 9013

# %%
for user in sample_to_process3:
    url = create_url(user)
    res = connect_to_endpoint(url, query_params)
    resdf = pd.DataFrame(res).transpose()
    userdf = userdf.append(resdf)
    print(sample_to_process3.index(user))
    time.sleep(3)
# Out:
# 200
# 0
# 200
# 1
# 200
# 2
# 200
# 3
# 200
# 4
# 200
# 5
# 200
# 6
# 200
# 7
# 200
# 8
# 200
# 9
# 200
# 10
# 200
# 11
# 200
# 12
# 200
# 13
# 200
# 14
# 200
# 15
# 200
# 16
# 200
# 17
# 200
# 18
# 200
# 19
# 200
# 20
# 200
# 21
# 200
# 22
# 200
# 23
# 200
# 24
# 200
# 25
# 200
# 26
# 200
# 27
# 200
# 28
# 200
# 29
# 200
# 30
# 200
# 31
# 200
# 32
# 200
# 33
# 200
# 34
# 200
# 35
# 200
# 36
# 200
# 37
# 200
# 38
# 200
# 39
# 200
# 40
# 200
# 41
# 200
# 42
# 200
# 43
# 200
# 44
# 200
# 45
# 200
# 46
# 200
# 47
# 200
# 48
# 200
# 49
# 200
# 50
# 200
# 51
# 200
# 52
# 200
# 53
# 200
# 54
# 200
# 55
# 200
# 56
# 200
# 57
# 200
# 58
# 200
# 59
# 200
# 60
# 200
# 61
# 200
# 62
# 200
# 63
# 200
# 64
# 200
# 65
# 200
# 66
# 200
# 67
# 200
# 68
# 200
# 69
# 200
# 70
# 200
# 71
# 200
# 72
# 200
# 73
# 200
# 74
# 200
# 75
# 200
# 76
# 200
# 77
# 200
# 78
# 200
# 79
# 200
# 80
# 200
# 81
# 200
# 82
# 200
# 83
# 200
# 84
# 200
# 85
# 200
# 86
# 200
# 87
# 200
# 88
# 200
# 89
# 200
# 90
# 200
# ...

# %%
 userdf.to_csv('20221201_userdf.csv')

# %%
userdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32932 entries, 0 to 32931
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32932 non-null  object
#  1   0           3084 non-null   object
#  2   created_at  29848 non-null  object
#  3   id          32932 non-null  object
#  4   name        29847 non-null  object
#  5   username    29848 non-null  object
#  6   withheld    1 non-null      object
# dtypes: object(7)
# memory usage: 1.8+ MB

# %%
maybebots = pd.read_csv('20221202_bots_csv.csv')

# %%
maybebots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3664 entries, 0 to 3663
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3664 non-null   int64
#  1   author_id   3664 non-null   object
#  2   2022-11-21  53 non-null     float64
#  3   2022-11-22  626 non-null    float64
#  4   2022-11-23  622 non-null    float64
#  5   2022-11-24  558 non-null    float64
#  6   2022-11-25  637 non-null    float64
#  7   2022-11-26  737 non-null    float64
#  8   2022-11-27  879 non-null    float64
#  9   2022-11-28  1310 non-null   float64
#  10  2022-11-29  434 non-null    float64
#  11  2022-11-30  174 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 343.6+ KB

# %%
userdf = pd.read_csv('20221201_userdf.csv')

# %%
userdf['id'] = userdf['id'].astype('str')
maybebots.author_id = maybebots.author_id.astype('str')

# %%
to_process = [x for x in maybebots.author_id if x not in userdf['id']]

# %%
len(idlist)
# Out:
# 3664

# %%
len(to_process)
# Out:
# 3664

# %%
idlist = list(maybebots.author_id)

# %%
userdf = pd.DataFrame()

# %%
for user in idlist:
    url = create_url(user)
    res = connect_to_endpoint(url, query_params)
    resdf = pd.DataFrame(res).transpose()
    userdf = userdf.append(resdf)
    print(idlist.index(user))
    time.sleep(3)
# Out:
# 200
# 0
# 200
# 1
# 200
# 2
# 200
# 3
# 200
# 4
# 200
# 5
# 200
# 6
# 200
# 7
# 200
# 8
# 200
# 9
# 200
# 10
# 200
# 11
# 200
# 12
# 200
# 13
# 200
# 14
# 200
# 15
# 200
# 16
# 200
# 17
# 200
# 18
# 200
# 19
# 200
# 20
# 200
# 21
# 200
# 22
# 200
# 23
# 200
# 24
# 200
# 25
# 200
# 26
# 200
# 27
# 200
# 28
# 200
# 29
# 200
# 30
# 200
# 31
# 200
# 32
# 200
# 33
# 200
# 34
# 200
# 35
# 200
# 36
# 200
# 37
# 200
# 38
# 200
# 39
# 200
# 40
# 200
# 41
# 200
# 42
# 200
# 43
# 200
# 44
# 200
# 45
# 200
# 46
# 200
# 47
# 200
# 48
# 200
# 49
# 200
# 50
# 200
# 51
# 200
# 52
# 200
# 53
# 200
# 54
# 200
# 55
# 200
# 56
# 200
# 57
# 200
# 58
# 200
# 59
# 200
# 60
# 200
# 61
# 200
# 62
# 200
# 63
# 200
# 64
# 200
# 65
# 200
# 66
# 200
# 67
# 200
# 68
# 200
# 69
# 200
# 70
# 200
# 71
# 200
# 72
# 200
# 73
# 200
# 74
# 200
# 75
# 200
# 76
# 200
# 77
# 200
# 78
# 200
# 79
# 200
# 80
# 200
# 81
# 200
# 82
# 200
# 83
# 200
# 84
# 200
# 85
# 200
# 86
# 200
# 87
# 200
# 88
# 200
# 89
# 200
# 90
# 200
# ...

# %%
userdf.to_csv('20221207_bots_created_dates.csv', encoding = 'utf-8-sig')

# %%
userdf.head()
# Out:
#                                                         0  \
# data                                                  NaN
# errors  {'parameter': 'id', 'resource_id': '25390452',...
# data                                                  NaN
# data                                                  NaN
# data                                                  NaN
#
#                       created_at        id  \
# data   2009-03-11 11:30:58+00:00  23749001
# errors                       NaT       NaN
# data   2009-03-25 22:55:42+00:00  26617160
# data   2009-05-21 19:23:05+00:00  41656176
# data   2009-06-08 14:36:53+00:00  45577593
#
#                                                    name    username  \
# data                                         Ceslieanne  ceslieanne
# errors                                              NaN         NaN
# data    Lotso Fight For HK 🧸⛑️☂🇺🇦 此自英雄大略之主，敢作敢為之事，意到即行。  LotsoforHK
# data                                        YangKai Liu  yangkailiu
# ...

# %%
userdf.created_at = [pd.to_datetime(x) for x in userdf.created_at]

# %%
userdf['create_date'] = [x.date() for x in userdf.created_at]

# %%
onlybefore = maybebots[(pd.isna(maybebots['2022-11-25'])== True) &
                      (pd.isna(maybebots['2022-11-26'])== True) &
                      (pd.isna(maybebots['2022-11-27'])== True) & 
                      (pd.isna(maybebots['2022-11-28'])== True) & 
                      (pd.isna(maybebots['2022-11-29'])== True) & 
                      (pd.isna(maybebots['2022-11-30'])== True)]

# %%
userdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3664 entries, data to data
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   0            2441 non-null   object
#  1   created_at   1223 non-null   datetime64[ns, UTC]
#  2   id           1223 non-null   object
#  3   name         1223 non-null   object
#  4   username     1223 non-null   object
#  5   create_date  1223 non-null   object
# dtypes: datetime64[ns, UTC](1), object(5)
# memory usage: 200.4+ KB

# %%
onlybefore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860 entries, 20 to 3657
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  860 non-null    int64
#  1   author_id   860 non-null    object
#  2   2022-11-21  9 non-null      float64
#  3   2022-11-22  498 non-null    float64
#  4   2022-11-23  434 non-null    float64
#  5   2022-11-24  234 non-null    float64
#  6   2022-11-25  0 non-null      float64
#  7   2022-11-26  0 non-null      float64
#  8   2022-11-27  0 non-null      float64
#  9   2022-11-28  0 non-null      float64
#  10  2022-11-29  0 non-null      float64
#  11  2022-11-30  0 non-null      float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 87.3+ KB

# %%
onlybefore.head()
# Out:
#     Unnamed: 0  author_id  2022-11-21  2022-11-22  2022-11-23  2022-11-24  \
# 20          20  188311776         NaN       198.0       200.0         NaN
# 24          24  215932455         NaN         NaN       200.0         NaN
# 32          32  295015889         NaN      1100.0       408.0         NaN
# 35          35  419378049         NaN         NaN       747.0       528.0
# 42          42  502594929         NaN      1091.0       407.0         NaN
#
#     2022-11-25  2022-11-26  2022-11-27  2022-11-28  2022-11-29  2022-11-30
# 20         NaN         NaN         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN         NaN         NaN
# 32         NaN         NaN         NaN         NaN         NaN         NaN
# 35         NaN         NaN         NaN         NaN         NaN         NaN
# 42         NaN         NaN         NaN         NaN         NaN         NaN

# %%
beforeuser = userdf[userdf['id'].isin(list(onlybefore.author_id))].copy()

# %%
beforeuser.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 411 entries, data to data
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   0            0 non-null      object
#  1   created_at   411 non-null    datetime64[ns, UTC]
#  2   id           411 non-null    object
#  3   name         411 non-null    object
#  4   username     411 non-null    object
#  5   create_date  411 non-null    object
# dtypes: datetime64[ns, UTC](1), object(5)
# memory usage: 22.5+ KB

# %%
beforeuser['create_year'] = [x.year for x in beforeuser.created_at]
beforeuser['create_month'] = [x.month for x in beforeuser.created_at]

# %%
beforeuser.create_year.value_counts()
# Out:
# 2022    273
# 2015    100
# 2020      9
# 2021      6
# 2018      6
# 2019      5
# 2016      5
# 2017      3
# 2013      1
# 2012      1
# 2011      1
# 2010      1
# Name: create_year, dtype: int64

# %%
beforeuser[beforeuser.create_year == 2022].create_month.value_counts().sum()
# Out:
# 273

# %%
130/273
# Out:
# 0.47619047619047616

# %%
afteruser = userdf[~userdf['id'].isin(list(onlybefore.author_id))].copy()

# %%
afteruser['create_year'] = [x.year for x in afteruser.created_at]
afteruser['create_month'] = [x.month for x in afteruser.created_at]

# %%
afteruser.create_year.value_counts().sum()
# Out:
# 812

# %%
afteruser[afteruser.create_year == 2022].create_month.value_counts().sum()
# Out:
# 425

# %%
425/812
# Out:
# 0.5233990147783252

# %%
132/425
# Out:
# 0.31058823529411766

# %%
maybebots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3664 entries, 0 to 3663
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3664 non-null   int64
#  1   author_id   3664 non-null   object
#  2   2022-11-21  53 non-null     float64
#  3   2022-11-22  626 non-null    float64
#  4   2022-11-23  622 non-null    float64
#  5   2022-11-24  558 non-null    float64
#  6   2022-11-25  637 non-null    float64
#  7   2022-11-26  737 non-null    float64
#  8   2022-11-27  879 non-null    float64
#  9   2022-11-28  1310 non-null   float64
#  10  2022-11-29  434 non-null    float64
#  11  2022-11-30  174 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 343.6+ KB
